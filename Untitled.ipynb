# %%
import pandas as pd
import numpy as np

# %%
url='https://raw.githubusercontent.com/jaydata-ml/Dataset/master/Beijing_Air-Quality_Data-Set.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %%
df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2          NO2            CO  \
# count  34368.000000  34580.000000  34395.000000  34310.00000  33767.000000
# mean      85.024136    112.223459     17.148603     55.52956   1370.395031
# ...

# %%
df.describe(include = [object])
# Out:
#            wd        station
# count   34985          35064
# unique     16              1
# top        NE  Wanshouxigong
# freq     3568          35064

# %%
df.columns
# Out:
# Index(['No', 'year', 'month', 'day', 'hour', 'PM2.5', 'PM10', 'SO2', 'NO2',
#        'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'station'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO    O3  \
# 0          1  2013      3    1     0    9.0    9.0   6.0   17.0   200.0  62.0
# 1          2  2013      3    1     1   11.0   11.0   7.0   14.0   200.0  66.0
# 2          3  2013      3    1     2    8.0    8.0   NaN   16.0   200.0  59.0
# 3          4  2013      3    1     3    8.0    8.0   3.0   16.0     NaN   NaN
# 4          5  2013      3    1     4    8.0    8.0   3.0    NaN   300.0  36.0
# 5          6  2013      3    1     5   10.0   10.0   4.0    8.0   200.0  64.0
# 6          7  2013      3    1     6    8.0    8.0   6.0   13.0   300.0  61.0
# 7          8  2013      3    1     7    8.0    8.0   8.0   20.0   300.0  54.0
# 8          9  2013      3    1     8    3.0    6.0   9.0   23.0   300.0  50.0
# 9         10  2013      3    1     9    3.0    6.0  10.0   18.0   300.0  56.0
# 10        11  2013      3    1    10    3.0    6.0  11.0   15.0   300.0  61.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
# No         35064 non-null int64
# year       35064 non-null int64
# month      35064 non-null int64
# day        35064 non-null int64
# hour       35064 non-null int64
# PM2.5      34368 non-null float64
# PM10       34580 non-null float64
# SO2        34395 non-null float64
# NO2        34310 non-null float64
# CO         33767 non-null float64
# O3         33986 non-null float64
# TEMP       35045 non-null float64
# PRES       35045 non-null float64
# DEWP       35045 non-null float64
# RAIN       35045 non-null float64
# wd         34985 non-null object
# WSPM       35051 non-null float64
# station    35064 non-null object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
df = df.drop(columns = 'No')

# %%
df['TEMP']
# Out:
# 0         0.3
# 1        -0.1
# 2        -0.6
# 3        -0.7
# 4        -0.9
# 5        -1.6
# 6        -2.4
# 7        -0.8
# 8         0.4
# 9         1.5
# 10        2.1
# 11        3.1
# 12        4.7
# 13        5.5
# 14        6.6
# 15        6.1
# 16        5.9
# 17        5.3
# 18        4.1
# 19        3.2
# 20        2.6
# 21        2.2
# 22        2.0
# 23        1.0
# 24        0.5
# 25       -0.3
# 26       -1.2
# 27       -2.9
# 28       -2.4
# 29       -1.2
#          ...
# 35034    13.8
# 35035    11.5
# 35036    11.7
# 35037    13.0
# 35038    12.9
# 35039    10.9
# 35040     9.9
# 35041     8.4
# 35042     8.6
# 35043     7.3
# 35044     7.0
# 35045     5.3
# 35046     9.5
# 35047     8.4
# 35048     9.2
# 35049    10.7
# 35050    12.0
# 35051    13.3
# 35052    12.9
# 35053    14.0
# 35054    14.6
# 35055    15.4
# 35056    14.9
# 35057    14.2
# 35058    13.4
# 35059    12.5
# 35060    11.6
# 35061    10.8
# 35062    10.5
# 35063     8.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 17 columns):
# year       35064 non-null int64
# month      35064 non-null int64
# day        35064 non-null int64
# hour       35064 non-null int64
# PM2.5      34368 non-null float64
# PM10       34580 non-null float64
# SO2        34395 non-null float64
# NO2        34310 non-null float64
# CO         33767 non-null float64
# O3         33986 non-null float64
# TEMP       35045 non-null float64
# PRES       35045 non-null float64
# DEWP       35045 non-null float64
# RAIN       35045 non-null float64
# wd         34985 non-null object
# WSPM       35051 non-null float64
# station    35064 non-null object
# dtypes: float64(11), int64(4), object(2)
# memory usage: 4.5+ MB

# %%
df.head()
# Out:
#    year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP    PRES  \
# 0  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3  1021.9
# 1  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1  1022.4
# 2  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6  1022.6
# 3  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7  1023.5
# 4  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9  1024.1
#
#    DEWP  RAIN   wd  WSPM        station
# 0 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3 -20.9   0.0   NW   2.6  Wanshouxigong
# 4 -21.7   0.0  WNW   2.5  Wanshouxigong

# %%
df.columns
# Out:
# Index(['year', 'month', 'day', 'hour', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO',
#        'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'station'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
''''x = np.array(df['hour'].head(21))
y1 = np.array(df['day'].head(21))
y2 = np.array(df['SO2'].head(21))
y3 = np.array(df['NO2'].head(21))
y4 = np.array(df['PM2.5'].head(21))
y5 = np.array(df['PM10'].head(21))
plt.plot(x, y2, lable = 'SO2 Level')
plt.plot(x, y3, lable = 'NO2 level')
plt.plot(x, y4, lable = 'PM2.5')
plt.plot(x, y5, lable = 'PM10')

plt.xlabel('Hour')
plt.ylable('Days')
plt.title('BG')
plt.legend()
plt.show()'''

X1  = np.array(df['hour'].head(21))
X2 = np.array(df['day'].head(21))
y1 = np.array(df['SO2'].head(21))
y2 = np.array(df['NO2'].head(21))
y3 = np.array(df['PM2.5'].head(21))
y4 = np.array(df['PM10'].head(21))
plt.plot(x, y1, label="SO2 Levels")
plt.plot(x, y2, label="NO2 Levels")
plt.plot(x, y3, label="PM2.5")
plt.plot(x, y4, label="PM10")


plt.xlabel("Hour")
plt.ylabel("Days")
plt.title("Beijing Air Quality")
#plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
x = np.array(df['SO2'])
plt.hist(x,histtype = 'bar')
plt.show()
