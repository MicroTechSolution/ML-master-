# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Data Set\\MinTruckSpeed.csv")

# %%
df
# Out:
#         id truckid driverid                      event   latitude   longitude  \
# 0        6     A50      A50                     normal  38.407650   13.000000
# 1        7     A51      A51                     normal  37.639097    0.000000
# 2        8     A19      A19                     normal  37.962146 -122.345526
# 3       10     A92      A92                     normal  37.484938 -119.966284
# 4       18     A10      A10                     normal  40.761243 -123.994778
# 5       21     A65      A65                     normal  37.484938 -119.966284
# 6       23     A94      A94  unsafe following distance  37.941325 -122.484704
# 7       26     A72      A72                     normal  37.957702 -121.290780
# 8       37     A56      A56                     normal  34.435829 -119.827639
# 9       51    A100     A100                     normal  34.136119 -117.865339
# 10      61     A22      A22                     normal  38.440467 -122.714431
# ...

# %%
df.loc[(df['latitude']<38)]
# Out:
#         id truckid driverid                      event   latitude   longitude  \
# 1        7     A51      A51                     normal  37.639097    0.000000
# 2        8     A19      A19                     normal  37.962146 -122.345526
# 3       10     A92      A92                     normal  37.484938 -119.966284
# 5       21     A65      A65                     normal  37.484938 -119.966284
# 6       23     A94      A94  unsafe following distance  37.941325 -122.484704
# 7       26     A72      A72                     normal  37.957702 -121.290780
# 8       37     A56      A56                     normal  34.435829 -119.827639
# 9       51    A100     A100                     normal  34.136119 -117.865339
# 14      74     A99      A99                     normal  34.500831 -117.185876
# 15      76     A16      A16                     normal  37.005782 -121.568275
# 16      99     A68      A68                     normal  34.354166 -119.059271
# ...

# %%
df.loc[(df['latitude']>38)]
# Out:
#         id truckid driverid                      event   latitude   longitude  \
# 0        6     A50      A50                     normal  38.407650   13.000000
# 4       18     A10      A10                     normal  40.761243 -123.994778
# 10      61     A22      A22                     normal  38.440467 -122.714431
# 11      62     A16      A16                     normal  39.017396 -122.057748
# 12      65     A39      A39                     normal  39.409608 -123.355566
# 13      70     A35      A35                     normal  39.409608 -123.355566
# 17     103     A88      A88                     normal  40.563763 -122.238892
# 19     107      A7       A7                     normal  39.409608 -123.355566
# 20     108     A31      A31                     normal  39.409608 -123.355566
# 21     114     A21      A21                     normal  38.752124 -121.288006
# 23     123     A39      A39                     normal  38.716687 -121.364422
# ...

# %%
df.loc[(df['city']=="Lodi")]
# Out:
#         id truckid driverid   event   latitude   longitude  city       state  \
# 69     325     A32      A32  normal  38.130197 -121.272447  Lodi  California
# 109    513     A17      A17  normal  38.130197 -121.272447  Lodi  California
# 167    740     A82      A82  normal  38.130197 -121.272447  Lodi  California
# 262   1151     A32      A32  normal  38.130197 -121.272447  Lodi  California
# 295   1297     A17      A17  normal  38.130197 -121.272447  Lodi  California
# 301   1314     A90      A90  normal  38.130197 -121.272447  Lodi  California
# 355   1534     A78      A78  normal  38.130197 -121.272447  Lodi  California
# 365   1578      A9       A9  normal  38.130197 -121.272447  Lodi  California
# 404   1819     A78      A78  normal  38.130197 -121.272447  Lodi  California
# 491   2192     A17      A17  normal  38.130197 -121.272447  Lodi  California
# 497   2206     A82      A82  normal  38.130197 -121.272447  Lodi  California
# ...

# %%
a=df.loc[(df['event'] == "normal")]

# %%
a
# Out:
#         id truckid driverid   event   latitude   longitude           city  \
# 0        6     A50      A50  normal  38.407650   13.000000     Occidental
# 1        7     A51      A51  normal  37.639097    0.000000        Modesto
# 2        8     A19      A19  normal  37.962146 -122.345526      San Pablo
# 3       10     A92      A92  normal  37.484938 -119.966284       Mariposa
# 4       18     A10      A10  normal  40.761243 -123.994778       Kneeland
# 5       21     A65      A65  normal  37.484938 -119.966284       Mariposa
# 7       26     A72      A72  normal  37.957702 -121.290780       Stockton
# 8       37     A56      A56  normal  34.435829 -119.827639         Goleta
# 9       51    A100     A100  normal  34.136119 -117.865339       Glendora
# 10      61     A22      A22  normal  38.440467 -122.714431     Santa Rosa
# 11      62     A16      A16  normal  39.017396 -122.057748       Arbuckle
# 12      65     A39      A39  normal  39.409608 -123.355566        Willits
# ...

# %%
b=df.loc[(df['city']=="Willits") & (df['latitude']>38)]

# %%
b
# Out:
#         id truckid driverid           event   latitude   longitude     city  \
# 12      65     A39      A39          normal  39.409608 -123.355566  Willits
# 13      70     A35      A35          normal  39.409608 -123.355566  Willits
# 19     107      A7       A7          normal  39.409608 -123.355566  Willits
# 20     108     A31      A31          normal  39.409608 -123.355566  Willits
# 30     159     A61      A61          normal  39.409608 -123.355566  Willits
# 37     181      A8       A8          normal  39.409608 -123.355566  Willits
# 49     246    A100     A100          normal  39.409608 -123.355566  Willits
# 63     289    A100     A100          normal  39.409608 -123.355566  Willits
# 94     431     A91      A91          normal  39.409608 -123.355566  Willits
# 99     449     A95      A95          normal  39.409608 -123.355566  Willits
# 107    503     A61      A61          normal  39.409608 -123.355566  Willits
# ...

# %%
c=df.loc[(df['city']=="Willits") | (df['latitude']>38)]

# %%
c
# Out:
#         id truckid driverid                      event   latitude   longitude  \
# 0        6     A50      A50                     normal  38.407650   13.000000
# 4       18     A10      A10                     normal  40.761243 -123.994778
# 10      61     A22      A22                     normal  38.440467 -122.714431
# 11      62     A16      A16                     normal  39.017396 -122.057748
# 12      65     A39      A39                     normal  39.409608 -123.355566
# 13      70     A35      A35                     normal  39.409608 -123.355566
# 17     103     A88      A88                     normal  40.563763 -122.238892
# 19     107      A7       A7                     normal  39.409608 -123.355566
# 20     108     A31      A31                     normal  39.409608 -123.355566
# 21     114     A21      A21                     normal  38.752124 -121.288006
# 23     123     A39      A39                     normal  38.716687 -121.364422
# ...

# %%
df.loc[:,["truckid","driverid"]]
# Out:
#      truckid driverid
# 0        A50      A50
# 1        A51      A51
# 2        A19      A19
# 3        A92      A92
# 4        A10      A10
# 5        A65      A65
# 6        A94      A94
# 7        A72      A72
# 8        A56      A56
# 9       A100     A100
# 10       A22      A22
# 11       A16      A16
# 12       A39      A39
# 13       A35      A35
# 14       A99      A99
# 15       A16      A16
# 16       A68      A68
# 17       A88      A88
# 18       A79      A79
# 19        A7       A7
# 20       A31      A31
# 21       A21      A21
# 22       A52      A52
# 23       A39      A39
# 24       A33      A33
# 25       A72      A72
# 26       A35      A35
# 27       A68      A68
# 28       A96      A96
# 29       A76      A76
# ...      ...      ...
# 1813     A95      A95
# 1814     A76      A76
# 1815     A85      A85
# 1816     A69      A69
# 1817     A83      A83
# 1818     A97      A97
# 1819      A1       A1
# 1820     A46      A46
# 1821     A73      A73
# ...

# %%
df.loc[:,["event","city"]]
# Out:
#                           event           city
# 0                        normal     Occidental
# 1                        normal        Modesto
# 2                        normal      San Pablo
# 3                        normal       Mariposa
# 4                        normal       Kneeland
# 5                        normal       Mariposa
# 6     unsafe following distance    San Quentin
# 7                        normal       Stockton
# 8                        normal         Goleta
# 9                        normal       Glendora
# 10                       normal     Santa Rosa
# 11                       normal       Arbuckle
# 12                       normal        Willits
# 13                       normal        Willits
# 14                       normal   Apple Valley
# 15                       normal         Gilroy
# 16                       normal    Santa Paula
# 17                       normal     Palo Cedro
# 18                       normal   San Fernando
# ...

# %%
df.loc[:10,["city","event"]]
# Out:
#            city                      event
# 0    Occidental                     normal
# 1       Modesto                     normal
# 2     San Pablo                     normal
# 3      Mariposa                     normal
# 4      Kneeland                     normal
# 5      Mariposa                     normal
# 6   San Quentin  unsafe following distance
# 7      Stockton                     normal
# 8        Goleta                     normal
# 9      Glendora                     normal
# 10   Santa Rosa                     normal

# %%
df.iloc[:10,2:5]
# Out:
#   driverid                      event   latitude
# 0      A50                     normal  38.407650
# 1      A51                     normal  37.639097
# 2      A19                     normal  37.962146
# 3      A92                     normal  37.484938
# 4      A10                     normal  40.761243
# 5      A65                     normal  37.484938
# 6      A94  unsafe following distance  37.941325
# 7      A72                     normal  37.957702
# 8      A56                     normal  34.435829
# 9     A100                     normal  34.136119

# %%
df.loc[(df['driverid'])=="A10"]
# Out:
#         id truckid driverid                      event   latitude   longitude  \
# 4       18     A10      A10                     normal  40.761243 -123.994778
# 81     364     A10      A10  unsafe following distance  37.941325 -122.484704
# 254   1118     A10      A10                     normal  34.354166 -119.059271
# 341   1468     A10      A10                     normal  34.354166 -119.059271
# 348   1516     A10      A10                     normal  37.941325 -122.484704
# 388   1695     A10      A10                     normal  39.409608 -123.355566
# 398   1758     A10      A10                     normal  34.354166 -119.059271
# 457   2077     A10      A10                     normal  34.354166 -119.059271
# 602   2660     A10      A10                     normal  40.761243 -123.994778
# 646   2837     A10      A10                     normal  39.409608 -123.355566
# 798   3538     A10      A10                     normal  39.409608 -123.355566
# ...
