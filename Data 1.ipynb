# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\starbucks_drinkMenu_expanded.csv")

# %%
df
# Out:
#                      Beverage_category  \
# 0                               Coffee
# 1                               Coffee
# 2                               Coffee
# 3                               Coffee
# 4              Classic Espresso Drinks
# 5              Classic Espresso Drinks
# 6              Classic Espresso Drinks
# 7              Classic Espresso Drinks
# 8              Classic Espresso Drinks
# 9              Classic Espresso Drinks
# 10             Classic Espresso Drinks
# 11             Classic Espresso Drinks
# 12             Classic Espresso Drinks
# 13             Classic Espresso Drinks
# 14             Classic Espresso Drinks
# 15             Classic Espresso Drinks
# 16             Classic Espresso Drinks
# 17             Classic Espresso Drinks
# 18             Classic Espresso Drinks
# 19             Classic Espresso Drinks
# 20             Classic Espresso Drinks
# 21             Classic Espresso Drinks
# 22             Classic Espresso Drinks
# ...

# %%
df.loc[(df['Calories']>200)]
# Out:
#                      Beverage_category  \
# 14             Classic Espresso Drinks
# 22             Classic Espresso Drinks
# 23             Classic Espresso Drinks
# 24             Classic Espresso Drinks
# 25             Classic Espresso Drinks
# 26             Classic Espresso Drinks
# 27             Classic Espresso Drinks
# 35             Classic Espresso Drinks
# 36             Classic Espresso Drinks
# 37             Classic Espresso Drinks
# 38             Classic Espresso Drinks
# 39             Classic Espresso Drinks
# 69           Signature Espresso Drinks
# 71           Signature Espresso Drinks
# 72           Signature Espresso Drinks
# 73           Signature Espresso Drinks
# 77           Signature Espresso Drinks
# 78           Signature Espresso Drinks
# 79           Signature Espresso Drinks
# 80           Signature Espresso Drinks
# 81           Signature Espresso Drinks
# 82           Signature Espresso Drinks
# 83           Signature Espresso Drinks
# ...

# %%
df.iloc[:4,:4]
# Out:
#   Beverage_category       Beverage Beverage_prep  Calories
# 0            Coffee  Brewed Coffee         Short         3
# 1            Coffee  Brewed Coffee          Tall         4
# 2            Coffee  Brewed Coffee        Grande         5
# 3            Coffee  Brewed Coffee         Venti         5

# %%
df.iloc[2:,:6]
# Out:
#                      Beverage_category  \
# 2                               Coffee
# 3                               Coffee
# 4              Classic Espresso Drinks
# 5              Classic Espresso Drinks
# 6              Classic Espresso Drinks
# 7              Classic Espresso Drinks
# 8              Classic Espresso Drinks
# 9              Classic Espresso Drinks
# 10             Classic Espresso Drinks
# 11             Classic Espresso Drinks
# 12             Classic Espresso Drinks
# 13             Classic Espresso Drinks
# 14             Classic Espresso Drinks
# 15             Classic Espresso Drinks
# 16             Classic Espresso Drinks
# 17             Classic Espresso Drinks
# 18             Classic Espresso Drinks
# 19             Classic Espresso Drinks
# 20             Classic Espresso Drinks
# 21             Classic Espresso Drinks
# 22             Classic Espresso Drinks
# 23             Classic Espresso Drinks
# 24             Classic Espresso Drinks
# ...

# %%
df.iloc[5:,:4]
# Out:
#                      Beverage_category  \
# 5              Classic Espresso Drinks
# 6              Classic Espresso Drinks
# 7              Classic Espresso Drinks
# 8              Classic Espresso Drinks
# 9              Classic Espresso Drinks
# 10             Classic Espresso Drinks
# 11             Classic Espresso Drinks
# 12             Classic Espresso Drinks
# 13             Classic Espresso Drinks
# 14             Classic Espresso Drinks
# 15             Classic Espresso Drinks
# 16             Classic Espresso Drinks
# 17             Classic Espresso Drinks
# 18             Classic Espresso Drinks
# 19             Classic Espresso Drinks
# 20             Classic Espresso Drinks
# 21             Classic Espresso Drinks
# 22             Classic Espresso Drinks
# 23             Classic Espresso Drinks
# 24             Classic Espresso Drinks
# 25             Classic Espresso Drinks
# 26             Classic Espresso Drinks
# 27             Classic Espresso Drinks
# ...

# %%
df.iloc[:10,:6]
# Out:
#          Beverage_category       Beverage      Beverage_prep  Calories  \
# 0                   Coffee  Brewed Coffee              Short         3
# 1                   Coffee  Brewed Coffee               Tall         4
# 2                   Coffee  Brewed Coffee             Grande         5
# 3                   Coffee  Brewed Coffee              Venti         5
# 4  Classic Espresso Drinks    Caffè Latte  Short Nonfat Milk        70
# 5  Classic Espresso Drinks    Caffè Latte            2% Milk       100
# 6  Classic Espresso Drinks    Caffè Latte            Soymilk        70
# 7  Classic Espresso Drinks    Caffè Latte   Tall Nonfat Milk       100
# 8  Classic Espresso Drinks    Caffè Latte            2% Milk       150
# 9  Classic Espresso Drinks    Caffè Latte            Soymilk       110
#
#    Total Fat (g)  Trans Fat (g)
# 0            0.1             0.0
# 1            0.1             0.0
# 2            0.1             0.0
# 3            0.1             0.0
# ...

# %%
df.iloc[6:,:5]
# Out:
#                      Beverage_category  \
# 6              Classic Espresso Drinks
# 7              Classic Espresso Drinks
# 8              Classic Espresso Drinks
# 9              Classic Espresso Drinks
# 10             Classic Espresso Drinks
# 11             Classic Espresso Drinks
# 12             Classic Espresso Drinks
# 13             Classic Espresso Drinks
# 14             Classic Espresso Drinks
# 15             Classic Espresso Drinks
# 16             Classic Espresso Drinks
# 17             Classic Espresso Drinks
# 18             Classic Espresso Drinks
# 19             Classic Espresso Drinks
# 20             Classic Espresso Drinks
# 21             Classic Espresso Drinks
# 22             Classic Espresso Drinks
# 23             Classic Espresso Drinks
# 24             Classic Espresso Drinks
# 25             Classic Espresso Drinks
# 26             Classic Espresso Drinks
# 27             Classic Espresso Drinks
# 28             Classic Espresso Drinks
# ...

# %%
df.loc[:5,["Beverage"]]
# Out:
#         Beverage
# 0  Brewed Coffee
# 1  Brewed Coffee
# 2  Brewed Coffee
# 3  Brewed Coffee
# 4    Caffè Latte
# 5    Caffè Latte

# %%
df.iloc[:20,[3,8]]
# Out:
#     Calories  Carbohydrates
# 0          3               5
# 1          4              10
# 2          5              10
# 3          5              10
# 4         70              75
# 5        100              85
# 6         70              65
# 7        100             120
# 8        150             135
# 9        110             105
# 10       130             150
# 11       190             170
# 12       150             130
# 13       170             190
# 14       240             220
# 15       190             170
# 16       110              60
# 17       130              70
# 18       110              55
# 19       170             100

# %%
df.loc[(df['Beverage']=="Brewed Coffee")]
# Out:
#   Beverage_category       Beverage Beverage_prep  Calories  Total Fat (g)  \
# 0            Coffee  Brewed Coffee         Short         3            0.1
# 1            Coffee  Brewed Coffee          Tall         4            0.1
# 2            Coffee  Brewed Coffee        Grande         5            0.1
# 3            Coffee  Brewed Coffee         Venti         5            0.1
#
#    Trans Fat (g)   Saturated Fat (g)   Sodium (mg)  Carbohydrates   \
# 0             0.0                0.0             0               5
# 1             0.0                0.0             0              10
# 2             0.0                0.0             0              10
# 3             0.0                0.0             0              10
#
#    Cholesterol   Dietary Fibre (g)  Sugars   Protein (g)  Vitamin A (% DV)   \
# 0            0                   0       0            0.3                0%
# 1            0                   0       0            0.5                0%
# ...

# %%
df.iloc[:11,:5]
# Out:
#           Beverage_category       Beverage       Beverage_prep  Calories  \
# 0                    Coffee  Brewed Coffee               Short         3
# 1                    Coffee  Brewed Coffee                Tall         4
# 2                    Coffee  Brewed Coffee              Grande         5
# 3                    Coffee  Brewed Coffee               Venti         5
# 4   Classic Espresso Drinks    Caffè Latte   Short Nonfat Milk        70
# 5   Classic Espresso Drinks    Caffè Latte             2% Milk       100
# 6   Classic Espresso Drinks    Caffè Latte             Soymilk        70
# 7   Classic Espresso Drinks    Caffè Latte    Tall Nonfat Milk       100
# 8   Classic Espresso Drinks    Caffè Latte             2% Milk       150
# 9   Classic Espresso Drinks    Caffè Latte             Soymilk       110
# 10  Classic Espresso Drinks    Caffè Latte  Grande Nonfat Milk       130
#
#     Total Fat (g)
# 0             0.1
# 1             0.1
# 2             0.1
# ...

# %%
df.iloc[10:21,[0,8]]
# Out:
#           Beverage_category  Carbohydrates
# 10  Classic Espresso Drinks             150
# 11  Classic Espresso Drinks             170
# 12  Classic Espresso Drinks             130
# 13  Classic Espresso Drinks             190
# 14  Classic Espresso Drinks             220
# 15  Classic Espresso Drinks             170
# 16  Classic Espresso Drinks              60
# 17  Classic Espresso Drinks              70
# 18  Classic Espresso Drinks              55
# 19  Classic Espresso Drinks             100
# 20  Classic Espresso Drinks             115

# %%
df.tail(20)
# Out:
#                      Beverage_category  \
# 222  Frappuccino® Light Blended Coffee
# 223  Frappuccino® Light Blended Coffee
# 224  Frappuccino® Light Blended Coffee
# 225  Frappuccino® Light Blended Coffee
# 226  Frappuccino® Light Blended Coffee
# 227  Frappuccino® Light Blended Coffee
# 228  Frappuccino® Light Blended Coffee
# 229         Frappuccino® Blended Crème
# 230         Frappuccino® Blended Crème
# 231         Frappuccino® Blended Crème
# 232         Frappuccino® Blended Crème
# 233         Frappuccino® Blended Crème
# 234         Frappuccino® Blended Crème
# 235         Frappuccino® Blended Crème
# 236         Frappuccino® Blended Crème
# 237         Frappuccino® Blended Crème
# 238         Frappuccino® Blended Crème
# 239         Frappuccino® Blended Crème
# 240         Frappuccino® Blended Crème
# 241         Frappuccino® Blended Crème
#
#                                          Beverage       Beverage_prep  \
# ...

# %%
df.loc[(df['Beverage_prep']=="2% Milk")]
# Out:
#              Beverage_category  \
# 5      Classic Espresso Drinks
# 8      Classic Espresso Drinks
# 11     Classic Espresso Drinks
# 14     Classic Espresso Drinks
# 17     Classic Espresso Drinks
# 20     Classic Espresso Drinks
# 23     Classic Espresso Drinks
# 26     Classic Espresso Drinks
# 29     Classic Espresso Drinks
# 32     Classic Espresso Drinks
# 35     Classic Espresso Drinks
# 38     Classic Espresso Drinks
# 45     Classic Espresso Drinks
# 48     Classic Espresso Drinks
# 51     Classic Espresso Drinks
# 54     Classic Espresso Drinks
# 63   Signature Espresso Drinks
# 66   Signature Espresso Drinks
# 69   Signature Espresso Drinks
# 72   Signature Espresso Drinks
# 75   Signature Espresso Drinks
# 78   Signature Espresso Drinks
# 81   Signature Espresso Drinks
# 84   Signature Espresso Drinks
# 87   Signature Espresso Drinks
# 90   Signature Espresso Drinks
# 93   Signature Espresso Drinks
# 96   Signature Espresso Drinks
# 107           Tazo® Tea Drinks
# ...

# %%
df.tail(30)
# Out:
#                      Beverage_category  \
# 212        Frappuccino® Blended Coffee
# 213        Frappuccino® Blended Coffee
# 214        Frappuccino® Blended Coffee
# 215        Frappuccino® Blended Coffee
# 216        Frappuccino® Blended Coffee
# 217  Frappuccino® Light Blended Coffee
# 218  Frappuccino® Light Blended Coffee
# 219  Frappuccino® Light Blended Coffee
# 220  Frappuccino® Light Blended Coffee
# 221  Frappuccino® Light Blended Coffee
# 222  Frappuccino® Light Blended Coffee
# 223  Frappuccino® Light Blended Coffee
# 224  Frappuccino® Light Blended Coffee
# 225  Frappuccino® Light Blended Coffee
# 226  Frappuccino® Light Blended Coffee
# 227  Frappuccino® Light Blended Coffee
# 228  Frappuccino® Light Blended Coffee
# 229         Frappuccino® Blended Crème
# 230         Frappuccino® Blended Crème
# 231         Frappuccino® Blended Crème
# 232         Frappuccino® Blended Crème
# 233         Frappuccino® Blended Crème
# 234         Frappuccino® Blended Crème
# ...

# %%
df.iloc[100:200,:]
# Out:
#                Beverage_category  \
# 100    Signature Espresso Drinks
# 101    Signature Espresso Drinks
# 102             Tazo® Tea Drinks
# 103             Tazo® Tea Drinks
# 104             Tazo® Tea Drinks
# 105             Tazo® Tea Drinks
# 106             Tazo® Tea Drinks
# 107             Tazo® Tea Drinks
# 108             Tazo® Tea Drinks
# 109             Tazo® Tea Drinks
# 110             Tazo® Tea Drinks
# 111             Tazo® Tea Drinks
# 112             Tazo® Tea Drinks
# 113             Tazo® Tea Drinks
# 114             Tazo® Tea Drinks
# 115             Tazo® Tea Drinks
# 116             Tazo® Tea Drinks
# 117             Tazo® Tea Drinks
# 118             Tazo® Tea Drinks
# 119             Tazo® Tea Drinks
# 120             Tazo® Tea Drinks
# 121             Tazo® Tea Drinks
# 122             Tazo® Tea Drinks
# 123             Tazo® Tea Drinks
# 124             Tazo® Tea Drinks
# 125             Tazo® Tea Drinks
# 126             Tazo® Tea Drinks
# ...

# %%
df.columns
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        ' Total Fat (g)', 'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        'Carbohydrates ', 'Cholesterol', ' Dietary Fibre (g)', 'Sugars',
#        ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) ', 'Caffeine'],
#       dtype='object')

# %%
df.loc[:,"Caffeine"]
# Out:
# 0      175.0
# 1      260.0
# 2      330.0
# 3      410.0
# 4       75.0
# 5       75.0
# 6       75.0
# 7       75.0
# 8       75.0
# 9       75.0
# 10     150.0
# 11     150.0
# 12     150.0
# 13     150.0
# 14     150.0
# 15     150.0
# 16      85.0
# 17      85.0
# 18      85.0
# 19      95.0
# 20      95.0
# 21      95.0
# 22     175.0
# 23     175.0
# 24     175.0
# 25     180.0
# 26     180.0
# 27     180.0
# 28      75.0
# 29      75.0
#        ...
# 212    110.0
# 213    110.0
# 214    145.0
# 215    145.0
# 216    145.0
# 217     70.0
# 218     95.0
# 219    120.0
# 220     70.0
# 221     95.0
# 222    130.0
# 223     65.0
# 224     90.0
# 225    120.0
# 226     70.0
# 227    105.0
# 228    165.0
# 229      0.0
# 230      0.0
# 231      0.0
# 232      0.0
# 233      0.0
# 234      0.0
# 235      0.0
# 236      0.0
# 237      0.0
# 238      0.0
# 239      0.0
# 240      0.0
# 241      0.0
# Name: Caffeine, Length: 242, dtype: float64

# %%
type(df["Caffeine"])
# Out:
# pandas.core.series.Series

# %%
df.loc[(df['Caffeine']>100) & (df['Beverage_prep']=="Grande")]
# Out:
#            Beverage_category                                 Beverage  \
# 2                     Coffee                            Brewed Coffee
# 42   Classic Espresso Drinks                          Caffè Americano
# 155    Shaken Iced Beverages  Iced Brewed Coffee (With Classic Syrup)
#
#     Beverage_prep  Calories  Total Fat (g)  Trans Fat (g)   Saturated Fat (g)  \
# 2          Grande         5            0.1             0.0                0.0
# 42         Grande        15              0             0.0                0.0
# 155        Grande        90            0.1             0.0                0.0
#
#       Sodium (mg)  Carbohydrates   Cholesterol   Dietary Fibre (g)  Sugars  \
# 2               0              10            0                   0       0
# 42              0              15            3                   0       0
# 155             0               5           21                   0      21
#
# ...

# %%
df.loc[(df['Calories']<100)]
# Out:
#                      Beverage_category  \
# 0                               Coffee
# 1                               Coffee
# 2                               Coffee
# 3                               Coffee
# 4              Classic Espresso Drinks
# 6              Classic Espresso Drinks
# 40             Classic Espresso Drinks
# 41             Classic Espresso Drinks
# 42             Classic Espresso Drinks
# 43             Classic Espresso Drinks
# 44             Classic Espresso Drinks
# 45             Classic Espresso Drinks
# 46             Classic Espresso Drinks
# 47             Classic Espresso Drinks
# 48             Classic Espresso Drinks
# 49             Classic Espresso Drinks
# 50             Classic Espresso Drinks
# 56             Classic Espresso Drinks
# 57             Classic Espresso Drinks
# 58             Classic Espresso Drinks
# 102                   Tazo® Tea Drinks
# 103                   Tazo® Tea Drinks
# 104                   Tazo® Tea Drinks
# ...

# %%
df.loc[:5,["Calories"]]
# Out:
#    Calories
# 0         3
# 1         4
# 2         5
# 3         5
# 4        70
# 5       100

# %%
x=df.loc[(df['Beverage_category'] == "Classic Espresso Drinks")]

# %%
x
# Out:
#           Beverage_category                                  Beverage  \
# 4   Classic Espresso Drinks                               Caffè Latte
# 5   Classic Espresso Drinks                               Caffè Latte
# 6   Classic Espresso Drinks                               Caffè Latte
# 7   Classic Espresso Drinks                               Caffè Latte
# 8   Classic Espresso Drinks                               Caffè Latte
# 9   Classic Espresso Drinks                               Caffè Latte
# 10  Classic Espresso Drinks                               Caffè Latte
# 11  Classic Espresso Drinks                               Caffè Latte
# 12  Classic Espresso Drinks                               Caffè Latte
# 13  Classic Espresso Drinks                               Caffè Latte
# 14  Classic Espresso Drinks                               Caffè Latte
# 15  Classic Espresso Drinks                               Caffè Latte
# ...

# %%
x.loc[(df['Beverage_category'])=="Shaken Iced Beverages"]
# Out:
# Empty DataFrame
# Columns: [Beverage_category, Beverage, Beverage_prep, Calories,  Total Fat (g), Trans Fat (g) , Saturated Fat (g),  Sodium (mg), Carbohydrates , Cholesterol,  Dietary Fibre (g), Sugars,  Protein (g) , Vitamin A (% DV) , Vitamin C (% DV),  Calcium (% DV) , Iron (% DV) , Caffeine]
# Index: []

# %%
df.iloc[:5,3]
# Out:
# 0     3
# 1     4
# 2     5
# 3     5
# 4    70
# Name: Calories, dtype: int64

# %%
b=df.loc[(df["Beverage_category"]=='Classic Espresso Drinks') & (df["Calories"]>100)]

# %%
b
# Out:
#           Beverage_category                                  Beverage  \
# 8   Classic Espresso Drinks                               Caffè Latte
# 9   Classic Espresso Drinks                               Caffè Latte
# 10  Classic Espresso Drinks                               Caffè Latte
# 11  Classic Espresso Drinks                               Caffè Latte
# 12  Classic Espresso Drinks                               Caffè Latte
# 13  Classic Espresso Drinks                               Caffè Latte
# 14  Classic Espresso Drinks                               Caffè Latte
# 15  Classic Espresso Drinks                               Caffè Latte
# 16  Classic Espresso Drinks       Caffè Mocha (Without Whipped Cream)
# 17  Classic Espresso Drinks       Caffè Mocha (Without Whipped Cream)
# 18  Classic Espresso Drinks       Caffè Mocha (Without Whipped Cream)
# 19  Classic Espresso Drinks       Caffè Mocha (Without Whipped Cream)
# ...

# %%
b.iloc[:,0:4]
# Out:
#           Beverage_category                                  Beverage  \
# 8   Classic Espresso Drinks                               Caffè Latte
# 9   Classic Espresso Drinks                               Caffè Latte
# 10  Classic Espresso Drinks                               Caffè Latte
# 11  Classic Espresso Drinks                               Caffè Latte
# 12  Classic Espresso Drinks                               Caffè Latte
# 13  Classic Espresso Drinks                               Caffè Latte
# 14  Classic Espresso Drinks                               Caffè Latte
# 15  Classic Espresso Drinks                               Caffè Latte
# 16  Classic Espresso Drinks       Caffè Mocha (Without Whipped Cream)
# 17  Classic Espresso Drinks       Caffè Mocha (Without Whipped Cream)
# 18  Classic Espresso Drinks       Caffè Mocha (Without Whipped Cream)
# 19  Classic Espresso Drinks       Caffè Mocha (Without Whipped Cream)
# ...

# %%
b.loc[:,["Beverage_category","Calories"]]
# Out:
#           Beverage_category  Calories
# 8   Classic Espresso Drinks       150
# 9   Classic Espresso Drinks       110
# 10  Classic Espresso Drinks       130
# 11  Classic Espresso Drinks       190
# 12  Classic Espresso Drinks       150
# 13  Classic Espresso Drinks       170
# 14  Classic Espresso Drinks       240
# 15  Classic Espresso Drinks       190
# 16  Classic Espresso Drinks       110
# 17  Classic Espresso Drinks       130
# 18  Classic Espresso Drinks       110
# 19  Classic Espresso Drinks       170
# 20  Classic Espresso Drinks       200
# 21  Classic Espresso Drinks       180
# 22  Classic Espresso Drinks       220
# 23  Classic Espresso Drinks       260
# 24  Classic Espresso Drinks       230
# 25  Classic Espresso Drinks       280
# 26  Classic Espresso Drinks       340
# 27  Classic Espresso Drinks       290
# 29  Classic Espresso Drinks       130
# 30  Classic Espresso Drinks       110
# 31  Classic Espresso Drinks       150
# 32  Classic Espresso Drinks       200
# ...
